# %% [markdown]
# If in vscode, please run the project on jupyter on website

# %%
using Pkg
using IJulia
jupyterlab(dir=pwd(), detached=true)
# Out:
# ┌ Info: running setenv(`'C:\Users\99029\.julia\conda\3\x86_64\Scripts\jupyter.exe' lab`,["WINDIR=C:\\WINDOWS", "PATH=C:\\Users\\99029\\.julia\\conda\\3\\x86_64\\Library\\bin;C:\\Users\\99029\\.julia\\conda\\3\\x86_64\\Scripts;C:\\Users\\99029\\.julia\\conda\\3\\x86_64\\Lib\\site-packages\\PySide6;C:\\Users\\99029\\.julia\\conda\\3\\x86_64\\Library\\bin;C:\\Program Files\\Microsoft\\jdk-11.0.16.101-hotspot\\bin;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\Program Files\\dotnet\\;C:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\iCLS\\;C:\\Program Files\\Intel\\Intel(R) Management Engine Components\\iCLS\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\msys64\\mingw64\\bin;E:\\msys64\\mingw64\\bin;C:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Program Files\\
# ...

# %%
import Pkg
Pkg.add("PyPlot")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\99029\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\99029\.julia\environments\v1.10\Manifest.toml`

# %%
using PyPlot

x=Array(1:10)
y=2*x

plot(x,y)
display(gcf())
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
x = [1;2;3;4;5]
y = [14;27;40;55;68]

plot(x, y, "b")
display(gcf())
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
x = Array(-5:0.1:5)
y = x.^2+3*x.-1

plot(x, y)
display(gcf())
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
