# %%
using Pkg
Pkg.add("MAT")
Pkg.add("NetCDF")
Pkg.add("XLSX")
# Out:
#     Updating registry at `C:\Users\99029\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed BufferedStreams ─ v1.2.2
#    Installed MAT ───────────── v0.10.7
#    Installed HDF5 ──────────── v0.17.2
#     Updating `C:\Users\99029\.julia\environments\v1.10\Project.toml`
#   [23992714] + MAT v0.10.7
#     Updating `C:\Users\99029\.julia\environments\v1.10\Manifest.toml`
#   [e1450e63] + BufferedStreams v1.2.2
#   [f67ccb44] + HDF5 v0.17.2
#   [23992714] + MAT v0.10.7
# Precompiling project...
#   ✓ BufferedStreams
#   ✓ HDF5
#   ✓ MAT
#   3 dependencies successfully precompiled in 133 seconds. 510 already precompiled. 2 skipped during auto due to previous errors.
#    Resolving package versions...
#    Installed LRUCache ─── v1.6.1
#    Installed NetCDF ───── v0.12.0
#    Installed DiskArrays ─ v0.4.6
#     Updating `C:\Users\99029\.julia\environments\v1.10\Project.toml`
#   [30363a11] + NetCDF v0.12.0
# ...

# %%
using MAT
using NetCDF
using XLSX
using DelimitedFiles
using PyPlot

# %%
x = Array(-100:2:100)
A = [x 2*x]
writedlm("test.txt", A)

# %%
A = readdlm("user\\sst_data.txt")

y = A[:,3]
x = 1:length(y)

plot(x,y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x000002DD3A45F560>
